# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 26.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 62.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 57.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# Train the model
train_results = model.train(
    data="/content/drive/MyDrive/ML_Internship/Manual_01/Tumor Detection.v8i.yolov11.zip (Unzipped Files)/data.yaml",
    epochs=20,
    imgsz=640,
    device='cpu'
)
# Out:
# Ultralytics 8.3.170 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/runs/detect/train/weights/best.pt")

# Perform object detection on an image
results = model("/content/drive/MyDrive/ML_Internship/Manual_01/Tumor Detection.v8i.yolov11.zip (Unzipped Files)/test/images/glioma_1025_jpg.rf.16f677de0fc84afa6b702f2fb8bdb3c2.jpg", save=True)
results[0].show()
# Out:
# image 1/1 /content/drive/MyDrive/ML_Internship/Manual_01/Tumor Detection.v8i.yolov11.zip (Unzipped Files)/test/images/glioma_1025_jpg.rf.16f677de0fc84afa6b702f2fb8bdb3c2.jpg: 640x640 1 glioma, 265.6ms
# Speed: 4.7ms preprocess, 265.6ms inference, 13.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/runs/detect/train/weights/best.pt")

# Perform object detection on an image
results = model("/content/drive/MyDrive/ML_Internship/Manual_01/Tumor Detection.v8i.yolov11.zip (Unzipped Files)/test/images", save=True)
# Out:
# image 1/191 /content/drive/MyDrive/ML_Internship/Manual_01/Tumor Detection.v8i.yolov11.zip (Unzipped Files)/test/images/glioma_1025_jpg.rf.16f677de0fc84afa6b702f2fb8bdb3c2.jpg: 640x640 1 glioma, 242.2ms
# image 2/191 /content/drive/MyDrive/ML_Internship/Manual_01/Tumor Detection.v8i.yolov11.zip (Unzipped Files)/test/images/glioma_1128_jpg.rf.e50d9e41b37fb138368e116b69077ff7.jpg: 640x640 2 pituitarys, 749.2ms
# image 3/191 /content/drive/MyDrive/ML_Internship/Manual_01/Tumor Detection.v8i.yolov11.zip (Unzipped Files)/test/images/glioma_1166_jpg.rf.493c4f22cb16b11580eabec42f51c3de.jpg: 640x640 1 meningioma, 283.5ms
# image 4/191 /content/drive/MyDrive/ML_Internship/Manual_01/Tumor Detection.v8i.yolov11.zip (Unzipped Files)/test/images/glioma_1246_jpg.rf.af4ca1f2e92bf1e7df0360136f128877.jpg: 640x640 2 gliomas, 216.1ms
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/runs/detect/train/weights/best.pt")  # pretrained YOLO11n model

# Run batched inference on a list of images
results = model("/content/drive/MyDrive/ML_Internship/Manual_01/Tumor Detection.v8i.yolov11.zip (Unzipped Files)/test/images/glioma_1025_jpg.rf.16f677de0fc84afa6b702f2fb8bdb3c2.jpg")  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    print(boxes)
# Out:
# image 1/1 /content/drive/MyDrive/ML_Internship/Manual_01/Tumor Detection.v8i.yolov11.zip (Unzipped Files)/test/images/glioma_1025_jpg.rf.16f677de0fc84afa6b702f2fb8bdb3c2.jpg: 640x640 1 glioma, 231.2ms
# Speed: 5.3ms preprocess, 231.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.])
# conf: tensor([0.8199])
# data: tensor([[304.7802, 236.6848, 423.8649, 310.6863,   0.8199,   1.0000]])
# id: None
# is_track: False
# orig_shape: (640, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[364.3225, 273.6856, 119.0847,  74.0015]])
# xywhn: tensor([[0.5693, 0.4276, 0.1861, 0.1156]])
# xyxy: tensor([[304.7802, 236.6848, 423.8649, 310.6863]])
# xyxyn: tensor([[0.4762, 0.3698, 0.6623, 0.4854]])

# %%
from ultralytics import YOLO
from ultralytics import SAM

# Load the YOLO model
yolo_model = YOLO("/content/runs/detect/train/weights/best.pt")  # pretrained YOLO model

# Run batched inference on a list of images
results = yolo_model("/content/drive/MyDrive/ML_Internship/Manual_01/Tumor Detection.v8i.yolov11.zip (Unzipped Files)/test/images/glioma_1025_jpg.rf.16f677de0fc84afa6b702f2fb8bdb3c2.jpg")  # return a list of Results objects

# Load the SAM model
sam_model = SAM("sam2_b.pt")

for result in results:
     class_ids = result.boxes.cls.int().tolist()  # noqa
     if len(class_ids):
         boxes = result.boxes.xyxy  # Boxes object for bbox outputs
         sam_results = sam_model(result.orig_img, bboxes=boxes, verbose=False, save=True, device="cpu")
# Out:
# image 1/1 /content/drive/MyDrive/ML_Internship/Manual_01/Tumor Detection.v8i.yolov11.zip (Unzipped Files)/test/images/glioma_1025_jpg.rf.16f677de0fc84afa6b702f2fb8bdb3c2.jpg: 640x640 1 glioma, 227.4ms
# Speed: 4.4ms preprocess, 227.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict
